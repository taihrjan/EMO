# %% [markdown]
# <a href="https://colab.research.google.com/github/taihrjan/EMO/blob/main/fooocus_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content

# 1. Полная очистка
# !rm -rf Fooocus

# 2. Клонируем заново
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus

# 3. Фикс pygit2 (чтобы не откатывал версию)
# !sed -i 's/pygit2==1.15.1/pygit2>=1.15.1/g' requirements_versions.txt

# 4. ВАЖНО: Исправляем "слипшиеся" строки в requirements_versions.txt
# Добавляем переносы строк после ключевых пакетов, которые часто ломаются при парсинге
# !sed -i 's/segment_anything==1.0/segment_anything==1.0\n/g' requirements_versions.txt
# !sed -i 's/supervision==0.6.0/supervision==0.6.0\n/g' requirements_versions.txt

# 5. Фикс версий FastAPI/Gradio для Python 3.13 (предотвращает ошибку dict/unhashable type)
# !echo "" >> requirements_versions.txt
# !echo "fastapi==0.104.1" >> requirements_versions.txt
# !echo "starlette==0.27.0" >> requirements_versions.txt
# !echo "pydantic==1.10.19" >> requirements_versions.txt

# 6. Запуск
# !python entry_with_update.py --share --always-high-vram
# Out:
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6735, done.
# remote: Total 6735 (delta 0), reused 0 (delta 0), pack-reused 6735 (from 1)
# Receiving objects: 100% (6735/6735), 33.35 MiB | 21.56 MiB/s, done.
# Resolving deltas: 100% (3849/3849), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# /content/Fooocus/build_launcher.py:9: SyntaxWarning: invalid escape sequence '\p'
#   .\python_embeded\python.exe -s Fooocus\entry_with_update.py {cmds} %*
# Python 3.13.15 (main, Aug  6 2026, 11:06:23) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
